# %%
import requests
from bs4 import BeautifulSoup

# %%
url = 'http://web.pcc.gov.tw/tps/pss/tender.do?searchMode=common&searchType=basic&method=search&isSpdt=&pageIndex=1'
playload = {
    'method':'search',
    'searchMethod':'true',
    'tenderUpdate':'',
    'searchTarget':'',
    'orgName':'',
    'orgId':'',
    'hid_1':'1',
    'tenderName':'',
    'tenderId':'',
    'tenderType':'tenderDeclaration',
    'tenderWay':'1,2,3,4,5,6,7,10,12',
    'tenderDateRadio':'on',
    'tenderStartDateStr':'105/02/12',
    'tenderEndDateStr':'105/02/18',
    'tenderStartDate':'105/02/12',
    'tenderEndDate':'105/02/18',
    'isSpdt':'N',
    'proctrgCate':'3',
    'radProctrgCate':'3',
    'btnQuery':'查詢',
    'hadUpdated':''
}
res = requests.post(url, data = playload)
soup = BeautifulSoup(res.text)
type(soup)
print soup
# Out:
# <html><head><link href="../styles/base.css" rel="stylesheet" type="text/css"/>
# <link href="/styles/text.css" rel="stylesheet" type="text/css"/>
# <link href="/styles/css.css" rel="stylesheet" type="text/css"/>
# <link href="../styles/confirm.css" rel="stylesheet" type="text/css"/>
# <style type="text/css">
# a:visited {
# 	text-decoration: none;
# 	color: #444444;
# }
#
# a:hover {
# 	text-decoration: none;
# 	color: #0066CC;
# }
#
# a:link {
# 	text-decoration: none;
# 	color: #444444;
# }
# </style>
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">
#
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="no-cache" http-equiv="Pragma"/>
# <meta content="no-cache" http-equiv="Cache-Control"/>
# <meta content="0" http-equiv="Expires"/>
# <title>政府電子採購網</title>
# <link href="/pis/styles/css_m.css" rel="stylesheet" type="text/css"/>
# ...

# %%
div = soup.select('#print_area')[0]
#type(div)
#print div
trs = div.select('tr')[1:-1]
#print len(trs)
for tr in trs:
    print 'http://web.pcc.gov.tw/tps/' + tr.select('a')[0]['href'][3:]
# Out:
# http://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=51811143
# http://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=51813272
# http://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=51813209
# http://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=51813134
# http://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=51813038
# http://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=51812755
# http://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=51812724
# http://web.pcc.gov.tw/tps/tpam/main/tps/tpam/tpam_tender_detail.do?searchMode=common&scope=F&primaryKey=51812688
# ...

# %%
url = 'http://www.1111.com.tw/job-bank/job-index.asp?ss=s&tt=1,2,4,16&wc=101103,101104,101106&si=1&ps=40&trans=1'
res = requests.get(url)
soup = BeautifulSoup(res.text)
#print soup

# %%
div = soup.select('#job_result')[0]
#type(div)
#print div
trs = div.select('ul')[1:]
print len(trs)
for tr in trs:
    ar = tr.select('a')[0]['href']
    print ar
# Out:
# http://www.1111.com.tw/job-bank/job-description.asp?eNo=78472991&agent=home_20160218
# http://www.1111.com.tw/job-bank/job-description.asp?eNo=78414799&agent=home_20160218
# http://www.1111.com.tw/job-bank/job-description.asp?eNo=78473012&agent=home_20160218
# http://www.1111.com.tw/job-bank/job-description.asp?eNo=75559406&agent=home_20160218
# http://www.1111.com.tw/job-bank/job-description.asp?eNo=78536934&agent=home_20160218
# http://www.1111.com.tw/job-bank/job-description.asp?eNo=78473059&agent=home_20160218
# http://www.1111.com.tw/job-bank/job-description.asp?eNo=76627010&agent=home_20160218
# http://www.1111.com.tw/job-bank/job-description.asp?eNo=78585665&agent=home_20160218
# http://www.1111.com.tw/job-bank/job-description.asp?eNo=77216886&agent=home_20160218
# http://www.1111.com.tw/job-bank/job-description.asp?eNo=77153652&agent=home_20160218
# http://www.1111.com.tw/job-bank/job-description.asp?eNo=76625716&agent=home_20160218
# ...

# %%
from math import ceil
num = soup.select('#showTotalPageCssBottom')[0].text.split()
n = int(num[3])
print n
# Out:
# 14

# %%
dib_url = 'http://www.1111.com.tw/job-bank/job-description.asp?eNo=78472991&agent=home_20160218'
res_bid = requests.get(dib_url)
soup = BeautifulSoup(res_bid.text)
to_file = soup.select('#wrap')[0]
print len(to_file)
file_id = dib_url.split('eNo=')[1]
f = open('\Users\BIG DATA\Desktop\ETL\{}.text'.format(file_id),'w')
f.write(to_file.prettify().encode('utf-8'))
f.close()
# Out:
# 177

# %%
url = 'http://www.1111.com.tw/job-bank/job-index.asp?ss=s&tt=1,2,4,16&wc=101103,101104,101106&si=1&ps=40&trans=1&page=1'
res = requests.get(url)
soup = BeautifulSoup(res.text)

#print len(trs)
from math import ceil
num = soup.select('#showTotalPageCssBottom')[0].text.split()
n = int(num[3])

url ='http://www.1111.com.tw/job-bank/job-index.asp?ss=s&tt=1,2,4,16&wc=101103,101104,101106&si=1&ps=40&trans=1&page={}'
urls = []
for i in xrange(0,n):
    urls.append(url.format(i+1))
    res = requests.get(urls[i])
    soup = BeautifulSoup(res.text)
    div = soup.select('#job_result')[0]
    trs = div.select('ul')[1:]
    for tr in trs:
        ar = tr.select('a')[0]['href']
        dib_url = ar
        res_bid = requests.get(dib_url)
        soup = BeautifulSoup(res_bid.text)
        to_file = soup.select('#wrap')[0]
        print len(to_file)
        file_id = dib_url.split('eNo=')[1]
        f = open('\Users\BIG DATA\Desktop\ETL\{}.text'.format(file_id),'w')
        f.write(to_file.prettify().encode('utf-8'))
        f.close()
        sleep(round(random.uniform(0,2),3))
# Out:
# 177
# 175
# 179
# 175
# 175
# 179
# 181
# 175
# 175
# 177
# 179
# 179
# 179
# 179
# 179
# 175
# 177
# 177
# 175
# 177
# 179
# 179
# 179
# 179
# 179
# 179
# 179
# 177
# 179
# 179
# 179
# 177
# 177
# 179
# 181
# 179
# 175
# 179
# 177
# 179
# 179
# 177
# 177
# 175
# 179
# 175
# 183
# 179
# 177
# 177
# 179
# 175
# 179
# 179
# 175
# 179
# 179
# 183
# 183
# 177
# 179
# 179
# 177
# 175
# 175
# 177
# 175
# 175
# 177
# 175
# 179
# 179
# 175
# 177
# 179
# 175
# 179
# 175
# 179
# 177
# 175
# 179
# 179
# 177
# 179
# 179
# 175
# 179
# 179
# 179
# 177
# 179
# 179
# 181
# 177
# 179
# 175
# 175
# 177
# 175
# 177
# 177
# 179
# 177
# 175
# 179
# 177
# 175
# 177
# 183
# 183
# 177
# 179
# 177
# 183
# 175
# 175
# 177
# 175
# 177
# 177
# 179
# 179
# 177
# 179
# 181
# 179
# 177
# 175
# 179
# 179
# 175
# 179
# 179
# 179
# 179
# 179
# 177
# 179
# 177
# 179
# 173
# 177
# 179
# 179
# 177
# 177
# 179
# 179
# 175
# 177
# 179
# 179
# 175
# 177
# 177
# 179
# 179
# 175
# 183
# 179
# 179
# 179
# 179
# 179
# 179
# ...
